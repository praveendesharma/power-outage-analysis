# %% [markdown]
# # Your Title Here
#
# **Name(s)**: (your name(s) here)
#
# **Website Link**: (your website link)

# %%
import pandas as pd
import numpy as np
from pathlib import Path

import plotly.express as px
pd.options.plotting.backend = 'plotly'

# from dsc80_utils import * # Feel free to uncomment and use this.

# %% [markdown]
# ## Step 1: Introduction

# %%
# TODO

# %% [markdown]
# ## Step 2: Data Cleaning and Exploratory Data Analysis

# %%
df=pd.read_excel("outage.xlsx")

df = df.drop(columns=['Major power outage events in the continental U.S.'])
df.columns = df.iloc[4]
df = df.drop(0)  
df = df.iloc[5:]
df=df.set_index('OBS')
df.columns
df
# Out:
# 4     YEAR MONTH    U.S._STATE POSTAL.CODE NERC.REGION      CLIMATE.REGION  \
# OBS
# 1     2011     7     Minnesota          MN         MRO  East North Central
# 2     2014     5     Minnesota          MN         MRO  East North Central
# 3     2010    10     Minnesota          MN         MRO  East North Central
# 4     2012     6     Minnesota          MN         MRO  East North Central
# 5     2015     7     Minnesota          MN         MRO  East North Central
# ...    ...   ...           ...         ...         ...                 ...
# 1530  2011    12  North Dakota          ND         MRO  West North Central
# 1531  2006   NaN  North Dakota          ND         MRO  West North Central
# 1532  2009     8  South Dakota          SD         RFC  West North Central
# 1533  2009     8  South Dakota          SD         MRO  West North Central
# 1534  2000   NaN        Alaska          AK        ASCC                 NaN
#
# ...

# %%
df.columns
# Out:
# Index(['YEAR', 'MONTH', 'U.S._STATE', 'POSTAL.CODE', 'NERC.REGION',
#        'CLIMATE.REGION', 'ANOMALY.LEVEL', 'CLIMATE.CATEGORY',
#        'OUTAGE.START.DATE', 'OUTAGE.START.TIME', 'OUTAGE.RESTORATION.DATE',
#        'OUTAGE.RESTORATION.TIME', 'CAUSE.CATEGORY', 'CAUSE.CATEGORY.DETAIL',
#        'HURRICANE.NAMES', 'OUTAGE.DURATION', 'DEMAND.LOSS.MW',
#        'CUSTOMERS.AFFECTED', 'RES.PRICE', 'COM.PRICE', 'IND.PRICE',
#        'TOTAL.PRICE', 'RES.SALES', 'COM.SALES', 'IND.SALES', 'TOTAL.SALES',
#        'RES.PERCEN', 'COM.PERCEN', 'IND.PERCEN', 'RES.CUSTOMERS',
#        'COM.CUSTOMERS', 'IND.CUSTOMERS', 'TOTAL.CUSTOMERS', 'RES.CUST.PCT',
#        'COM.CUST.PCT', 'IND.CUST.PCT', 'PC.REALGSP.STATE', 'PC.REALGSP.USA',
#        'PC.REALGSP.REL', 'PC.REALGSP.CHANGE', 'UTIL.REALGSP', 'TOTAL.REALGSP',
#        'UTIL.CONTRI', 'PI.UTIL.OFUSA', 'POPULATION', 'POPPCT_URBAN',
#        'POPPCT_UC', 'POPDEN_URBAN', 'POPDEN_UC', 'POPDEN_RURAL',
# ...

# %%
df['OUTAGE.DURATION']/60#.describe()
# Out:
# OBS
# 1           51.0
# 2       0.016667
# 3           50.0
# 4           42.5
# 5           29.0
#           ...
# 1530        12.0
# 1531         NaN
# 1532    0.983333
# 1533    3.016667
# 1534         NaN
# Name: OUTAGE.DURATION, Length: 1534, dtype: object

# %%
# ... existing code ...

## Step 2: Data Cleaning and Exploratory Data Analysis

# Assuming your DataFrame is called 'df'
fig = px.scatter(
    df,
    x='OUTAGE.DURATION',  # Adjust column name if different in your dataset
    y='POPDEN_URBAN',  # Adjust column name if different in your dataset
    title='Outage Duration vs Population Density',
    labels={
        'OUTAGE.DURATION': 'Outage Duration',
        'POPULATION.DENSITY': 'Population Density'
    },
    opacity=0.6,
    render_mode='webgl'  # For better performance with large datasets
)

# Update layout for better readability
fig.update_layout(
    template='plotly_white',
    title_x=0.5,  # Center the title
)

fig.show()

# ... existing code ...

# %% [markdown]
# ## Step 3: Assessment of Missingness

# %%
# TODO

# %% [markdown]
# ## Step 4: Hypothesis Testing

# %%
# TODO

# %% [markdown]
# ## Step 5: Framing a Prediction Problem

# %%
# TODO

# %% [markdown]
# ## Step 6: Baseline Model

# %%
# TODO

# %% [markdown]
# ## Step 7: Final Model

# %%
# TODO

# %% [markdown]
# ## Step 8: Fairness Analysis

# %%
# TODO
